# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !pip install lux-api

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lux
df_2016 = pd.read_csv('/gdrive/MyDrive/Progetto DWM/Data/properties_2016.csv', low_memory = False)
df_2017 = pd.read_csv('/gdrive/MyDrive/Progetto DWM/Data/properties_2017.csv', low_memory = False)

# %%
print('2016 Dataset')
to_drop = None
for col in df_2016:
    column_report = df_2016[col].value_counts(dropna=False)
    column_size = df_2016[col].size
    column_not_NaN = df_2016[col].count(level = None)
    empty_percentage = 100 * (column_size - column_not_NaN) / column_size
    if empty_percentage < 15.0:
      print("[" + df_2016[col].name + "] " + str(empty_percentage) + " %")
    else:
      print("[" + df_2016[col].name + "] " + str(empty_percentage) + " % - DROP")
# Out:
# 2016 Dataset
# [parcelid] 0.0 %
# [airconditioningtypeid] 72.81541006901676 % - DROP
# [architecturalstyletypeid] 99.79696618369786 % - DROP
# [basementsqft] 99.94546460106585 % - DROP
# [bathroomcnt] 0.38395868709041925 %
# [bedroomcnt] 0.3835567062628948 %
# [buildingclasstypeid] 99.57694867743282 % - DROP
# [buildingqualitytypeid] 35.06374913448503 % - DROP
# [calculatedbathnbr] 4.3183460364857895 %
# [decktypeid] 99.42731131438686 % - DROP
# [finishedfloor1squarefeet] 93.20930438222749 % - DROP
# [calculatedfinishedsquarefeet] 1.861338723449585 %
# [finishedsquarefeet12] 9.24666448033761 %
# [finishedsquarefeet13] 99.74300025760272 % - DROP
# [finishedsquarefeet15] 93.60857183916613 % - DROP
# [finishedsquarefeet50] 93.20930438222749 % - DROP
# [finishedsquarefeet6] 99.26300165113625 % - DROP
# [fips] 0.38312122703307666 %
# [fireplacecnt] 89.5271600021037 % - DROP
# [fullbathcnt] 4.3183460364857895 %
# [garagecarcnt] 70.41196670124819 % - DROP
# ...
